# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pandas as pd
import numpy as np
from data import clean_and_split_nba_data as clean
from data import split_data as split
from data import resample_nba_data as re
from models import plot_validation_curve as vc
from models import eval_model as evm
import xgboost as xgb
from hyperopt import Trials, STATUS_OK, tpe, hp, fmin
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("../data/raw/train.csv")
df
# Out:
#       Id_old     Id  GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA  ...  FTA  \
# 0      10556   3799  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  ...  2.9
# 1       5342   3800  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  ...  3.6
# 2       5716   3801  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  ...  0.6
# 3      13790   3802  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  ...  1.5
# 4       5470   3803  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  ...  0.5
# ...      ...    ...  ..   ...   ...  ...  ...   ...      ...  ...  ...  ...
# 7995    2996  11794  32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  ...  0.6
# 7996   11679  11795  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1  ...  0.4
# 7997    5537  11796  85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  ...  3.9
# 7998    1292  11797  39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  ...  0.7
# 7999    2900  11798  49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  ...  1.3
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0     72.1   2.2   2.0  3.8  3.2  1.1  0.2  1.6            1
# 1     67.8   3.6   3.7  6.6  0.7  0.5  0.6  1.4            1
# 2     75.7   0.6   1.8  2.4  0.8  0.4  0.2  0.6            1
# 3     66.9   0.8   2.0  3.0  1.8  0.4  0.1  1.9            1
# 4     54.0   2.4   2.7  4.9  0.4  0.4  0.6  0.7            1
# ...    ...   ...   ...  ...  ...  ...  ...  ...          ...
# 7995  65.7   0.3   1.8  1.9  0.5  0.3  0.2  0.4            1
# 7996  70.1   1.0   1.1  2.0  0.1  0.0  0.3  0.3            1
# 7997  69.7   1.0   2.1  3.1  3.4  1.2  0.2  1.8            1
# 7998  74.3   0.4   0.6  0.9  0.2  0.3  0.3  0.5            1
# 7999  70.1   0.1   1.1  1.2  3.5  0.9 -0.3  1.4            1
#
# [8000 rows x 22 columns]

# %%
df_upsampled, df_downsampled = re.resample_nba_data(df)
# Out:
# df_minority.shape (1331, 22)  df_majority.shape (6669, 22)
# df_minority.shape 0    1331
# Name: TARGET_5Yrs, dtype: int64  df_majority.shape 1    6669
# Name: TARGET_5Yrs, dtype: int64
# df_upsampled  0    6669
# 1    6669
# Name: TARGET_5Yrs, dtype: int64
# 0    6669
# 1    6669
# Name: TARGET_5Yrs, dtype: int64
# df_downsampled  0    1331
# 1    1331
# Name: TARGET_5Yrs, dtype: int64
# 0    1331
# 1    1331
# Name: TARGET_5Yrs, dtype: int64

# %%
df_upsampled.shape,df_downsampled.shape
# Out:
# ((13338, 22), (2662, 22))

# %%
x_data, x_train, x_val, x_test, y_data , y_train, y_val,  y_test =  clean.clean_and_split_nba_data(df_downsampled)
# Out:
# Index(['GP', 'MIN', 'PTS', 'FGM', 'FGA', '3P Made', '3PA', 'FTM', 'FTA',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'CALC3P%', 'CALCFG%',
#        'CALCFT%'],
#       dtype='object')

# %%
x_data.columns
# Out:
# Index(['GP', 'MIN', 'PTS', 'FGM', 'FGA', '3P Made', '3PA', 'FTM', 'FTA',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'CALC3P%', 'CALCFG%',
#        'CALCFT%'],
#       dtype='object')

# %%
evm.eval_model(xgb.XGBClassifier(random_state=8, verbosity=1,use_label_encoder=False),x_train,y_train,x_val,y_val)
# Out:
# [13:39:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Validation</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.6594591</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.62206573</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.64301552</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.68075117</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.6092437</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.62206573</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 1.5rem; margin-bottom: 1rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Training</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">1.0</span></div></div></div>
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=8,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=1)
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                importance_type='gain', interaction_constraints='',
#                learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                min_child_weight=1, missing=nan, monotone_constraints='()',
#                n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=8,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#                tree_method='exact', use_label_encoder=False,
#                validate_parameters=1, verbosity=1),
#  1.0,
#  0.6594591020300204)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc'
                                                    ),
                    hyperparameter='min_child_weight',
                    hyperparameter_value=[1,2,3,5,10,15,20,30,40,50,100,500,550,560,570,580,590,600,700],
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc'),
                    hyperparameter='min_child_weight',
                    hyperparameter_value=range(100,350,50),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200
                                                    ),
                    hyperparameter='colsample_bytree',
                    hyperparameter_value=np.arange( 0.1, 1.0, 0.05),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200
                                                    
                                                    ),
                    hyperparameter='colsample_bytree',
                    hyperparameter_value=np.arange( 0.35, 0.45, 0.01),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42
                                                    
                                                    ),
                    hyperparameter='subsample',
                    hyperparameter_value=np.arange( 0.1, 1.0, 0.05),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42
                                                    ),
                    hyperparameter='subsample',
                    hyperparameter_value=np.arange( 0.99, 1.0, 0.001),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42,
                                                     subsample=0.999
                                                    ),
                    hyperparameter='reg_lambda',
                    hyperparameter_value=np.arange( 0.1, 1.0, 0.05),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42,
                                                     subsample=0.999
                                                    ),
                    hyperparameter='reg_alpha',
                    hyperparameter_value=np.arange( 0.1, 1.0, 0.05),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42,
                                                     subsample=0.999
                                                    ),
                    hyperparameter='max_depth',
                    hyperparameter_value=range(1,50,1),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42,
                                                     subsample=0.999                                                   
                                                    ),
                    hyperparameter='learning_rate',
                    hyperparameter_value=np.arange( 0.1, 1.0, 0.05),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
vc.plot_validation_curve(estimator=xgb.XGBClassifier(random_state=8, 
                                                     verbosity=1,
                                                     use_label_encoder=False,
                                                     objective ='binary:logistic',
                                                     eval_metric='auc',
                                                    min_child_weight=200,
                                                     colsample_bytree=0.42,
                                                     subsample=0.999                                                   
                                                    ),
                    hyperparameter='learning_rate',
                    hyperparameter_value=np.arange( 0.28, 0.305, 0.001),
                    x=x_data,
                    y=y_data,
                    title="XGBoost",
                    cv=5)

# %%
xgboost1=xgb.XGBClassifier(random_state=8, 
                verbosity=1,
                use_label_encoder=False,
                objective ='binary:logistic',
                eval_metric='auc',
                min_child_weight=200,
                colsample_bytree=0.42,
                subsample=0.999,
                learning_rate=0.291)
evm.eval_model(xgboost1,x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Validation</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.68330799</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.63849765</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.65625</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.69014085</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.62553191</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.63849765</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 1.5rem; margin-bottom: 1rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Training</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.68585426</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.64063417</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.64210526</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.64512338</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.63911525</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.64063417</span></div></div></div>
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.42, eval_metric='auc',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.291, max_delta_step=0,
#               max_depth=6, min_child_weight=200, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, random_state=8, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.999, tree_method='exact',
#               use_label_encoder=False, validate_parameters=1, verbosity=1)
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=0.42, eval_metric='auc',
#                gamma=0, gpu_id=-1, importance_type='gain',
#                interaction_constraints='', learning_rate=0.291, max_delta_step=0,
#                max_depth=6, min_child_weight=200, missing=nan,
#                monotone_constraints='()', n_estimators=100, n_jobs=8,
#                num_parallel_tree=1, random_state=8, reg_alpha=0, reg_lambda=1,
#                scale_pos_weight=1, subsample=0.999, tree_method='exact',
#                use_label_encoder=False, validate_parameters=1, verbosity=1),
#  0.6858542559706062,
#  0.6833079856289537)

# %%
from sklearn.model_selection import cross_val_score
space = {
    'learning_rate' : hp.quniform('learning_rate',  0.28, 0.305, 0.0001),
    'min_child_weight' : hp.quniform('min_child_weight',180,230,1),
    'colsample_bytree' : hp.quniform('colsample_bytree', 0.40, 0.45, 0.0001),
    'subsample' : hp.quniform('subsample',0.99, 1.0, 0.0001)
}
space
# Out:
# {'learning_rate': <hyperopt.pyll.base.Apply at 0x270c577ba00>,
#  'min_child_weight': <hyperopt.pyll.base.Apply at 0x270c457f730>,
#  'colsample_bytree': <hyperopt.pyll.base.Apply at 0x270c457f640>,
#  'subsample': <hyperopt.pyll.base.Apply at 0x270c456ed00>}

# %%
def objective(space):
   
    xgboost = xgb.XGBClassifier(
        random_state=8,
        learning_rate = space['learning_rate'],
        min_child_weight = space['min_child_weight'],
        colsample_bytree = space['colsample_bytree'],
        subsample = space['subsample'],
        use_label_encoder=False,
        objective ='binary:logistic',
        eval_metric ='auc'
    )
    
    acc = cross_val_score(xgboost, x_train, y_train, cv=10,scoring='roc_auc').mean()

    return{'loss': 1-acc, 'status': STATUS_OK }
best = fmin(
    fn=objective,   
    space=space,       
    algo=tpe.suggest,       
    max_evals=5
)
print("Best: ", best)
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.43s/trial, best loss: 0.5]
# Best:  {'colsample_bytree': 0.41050000000000003, 'learning_rate': 0.2871, 'min_child_weight': 225.0, 'subsample': 0.997}

# %%
xgboos2=xgb.XGBClassifier(
        random_state=8,
        learning_rate = best['learning_rate'],
        min_child_weight = best['min_child_weight'],
        colsample_bytree = best['colsample_bytree'],
        subsample = best['subsample'],
        use_label_encoder=False,
        objective ='binary:logistic',
        eval_metric ='auc'
    )
evm.eval_model(xgboos2,x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Validation</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.5</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.5</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.66666667</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.5</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.5</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 1.5rem; margin-bottom: 1rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Training</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.5</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.4997064</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.66640564</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.4997064</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.4997064</span></div></div></div>
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.41050000000000003,
#               eval_metric='auc', gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.2871,
#               max_delta_step=0, max_depth=6, min_child_weight=225.0,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=8, num_parallel_tree=1, random_state=8, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=0.997,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)
# (XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=0.41050000000000003,
#                eval_metric='auc', gamma=0, gpu_id=-1, importance_type='gain',
#                interaction_constraints='', learning_rate=0.2871,
#                max_delta_step=0, max_depth=6, min_child_weight=225.0,
#                missing=nan, monotone_constraints='()', n_estimators=100,
#                n_jobs=8, num_parallel_tree=1, random_state=8, reg_alpha=0,
#                reg_lambda=1, scale_pos_weight=1, subsample=0.997,
#                tree_method='exact', use_label_encoder=False,
#                validate_parameters=1, verbosity=None),
#  0.5,
#  0.5)

# %%
evm.get_performance(xgboost1, x_test, y_test, "Test", True)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Validation</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.66840556</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.61163227</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.61016949</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.60674157</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.61363636</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.61163227</span></div></div></div>
# (0.6684055644729802,
#  0.6116322701688556,
#  0.6101694915254238,
#  0.6136363636363636,
#  0.6067415730337079,
#  0.6116322701688556)

# %%
evm.get_performance(xgboos2, x_test, y_test, "Test", True)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 700; color: ghostwhite;">Validation</div><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; border-radius: 4px; box-shadow: 0 4px 6px 2px black; text-align: center; background: #3B4252"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">0.5</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C">0.50093809</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">0.6675</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">1.0</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">0.50093809</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">0.50093809</span></div></div></div>
# (0.5, 0.50093808630394, 0.6675, 0.50093808630394, 1.0, 0.50093808630394)

# %%
from joblib import dump
dump(xgboost1,  '../models/sp_wk3_xgboost_downsample_model.joblib')
# Out:
# ['../models/sp_wk3_xgboost_downsample_model.joblib']
